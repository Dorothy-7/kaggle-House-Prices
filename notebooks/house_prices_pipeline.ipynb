# %% [markdown]
# # Kaggle House Prices — 本番パイプライン
#
# カーネルはプロジェクト直下 `Python3/` をカレントにしてください。`src` をパスに通してから `house_prices.cli.run` を呼びます。

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().resolve()
if not (ROOT / "src" / "house_prices").is_dir():
    raise RuntimeError("カレントを Python3（src/house_prices があるフォルダ）にしてください")
sys.path.insert(0, str(ROOT / "src"))

from house_prices.cli import run

# 既定: データ `data/`、出力 `outputs/submission_house_prices_best.csv`
run()
